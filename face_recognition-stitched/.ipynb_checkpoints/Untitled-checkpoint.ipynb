# %%
import numpy as np
from PIL import Image

# %%
#importing images
image1 = Image.open('face1.jpg')
image2 = Image.open('face2.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.title("Image1")
plt.imshow(image1)

# %%
plt.title("Image2")
plt.imshow(image2)

# %%
def merge_imgs(image1,image2):
    image1_size = image1.size
    image2 = image2.resize(image1_size)
    merged_image = Image.new('RGB',(2*image1_size[0], image1_size[1]), (250,250,250))
    merged_image.paste(image1,(0,0))
    merged_image.paste(image2,(image1_size[0],0))
    return merged_image

# %%
new_img = merge_imgs(image2,image1)

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
img = numpy.array(new_img)


gray = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
faces  = face_cascade.detectMultiScale(gray,1.1,4)

font = cv2.FONT_HERSHEY_SIMPLEX 


for(x,y,w,h) in faces:

    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

    img_face = gray[y:y+h,x:x+w]
    img_face = cv2.resize(img_face,(60,60))

    img_face = np.reshape(img_face,(1,60,60,3))

    cntr[labels[name[0]]]+=1;
    


# Display
cv2.imshow('img', img)
